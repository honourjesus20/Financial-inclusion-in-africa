# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('train.csv')
data.head()
# Out:
#   country  year    uniqueid bank_account location_type cellphone_access  \
# 0   Kenya  2018  uniqueid_1          Yes         Rural              Yes
# 1   Kenya  2018  uniqueid_2           No         Rural               No
# 2   Kenya  2018  uniqueid_3          Yes         Urban              Yes
# 3   Kenya  2018  uniqueid_4           No         Rural              Yes
# 4   Kenya  2018  uniqueid_5           No         Urban               No
#
#    household_size  age_of_respondent gender_of_respondent  \
# 0               3                 24               Female
# 1               5                 70               Female
# 2               5                 26                 Male
# 3               5                 34               Female
# 4               8                 26                 Male
#
#   relationship_with_head           marital_status  \
# 0                 Spouse  Married/Living together
# 1      Head of Household                  Widowed
# ...

# %%
data.shape
# Out:
# (23524, 13)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23524 entries, 0 to 23523
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 23524 non-null  object
#  1   year                    23524 non-null  int64
#  2   uniqueid                23524 non-null  object
#  3   bank_account            23524 non-null  object
#  4   location_type           23524 non-null  object
#  5   cellphone_access        23524 non-null  object
#  6   household_size          23524 non-null  int64
#  7   age_of_respondent       23524 non-null  int64
#  8   gender_of_respondent    23524 non-null  object
#  9   relationship_with_head  23524 non-null  object
#  10  marital_status          23524 non-null  object
#  11  education_level         23524 non-null  object
#  12  job_type                23524 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 2.3+ MB

# %%
data._get_numeric_data().columns
# Out:
# Index(['year', 'household_size', 'age_of_respondent'], dtype='object')

# %% [markdown]
# #### DATA PREPROCESSING / EDA

# %%
data['gender']= data['gender_of_respondent']

# %%
sns.countplot(data=data,x='gender',hue='country')

# %%
data.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type', 'gender'],
#       dtype='object')

# %%
sns.countplot(data=data,x='gender',hue='bank_account')

# %%
sns.countplot(data=data,x='country',hue='bank_account')

# %%
sns.countplot(data=data,x='country',hue='cellphone_access')

# %%
sns.countplot(data=data,x='country',hue='education_level')

# %%
sns.countplot(data=data,x='country',hue='job_type')

# %%
sns.countplot(data=data,x='gender',hue='job_type')

# %%
sns.countplot(data=data,x='job_type',hue='location_type')

# %%
sns.countplot(data=data,x='location_type',hue='job_type')

# %%
sns.countplot(data=data,x='gender',hue='location_type')

# %%
sns.countplot(data=data,x='location_type',hue='household_size')

# %%
sns.countplot(data=data,x='household_size',hue='location_type')

# %%
sns.countplot(data=data,x='country',hue='household_size')

# %%
sns.countplot(data=data,x='household_size',hue='country')

# %%
data['age']=data['age_of_respondent'].mean()

# %%
sns.countplot(data=data,x='age',hue='gender')

# %%
sns.countplot(data=data,x='gender',hue='age')

# %%
sns.countplot(data=data,x='country',hue='marital_status')

# %%
sns.countplot(data=data,x='gender',hue='marital_status')

# %%
sns.countplot(data=data,x='job_type',hue='marital_status')

# %%
sns.countplot(data=data,x='marital_status',hue='job_type')

# %%
sns.countplot(data=data,x='marital_status',hue='year')

# %%
sns.countplot(data=data,x='marital_status',hue='age')

# %%
sns.countplot(data=data,x='bank_account',hue='cellphone_access')

# %%
sns.countplot(data=data,x='bank_account',hue='job_type')

# %%
sns.countplot(data=data,x='education_level',hue='marital_status')

# %%
sns.countplot(data=data,x='bank_account',hue='relationship_with_head')

# %%
sns.countplot(data=data,x='bank_account',hue='country')

# %%
#checking for outliers
int_col=['year', 'household_size', 'age_of_respondent']
for i in int_col:
    plt.figure()
    plt.boxplot(data[i])

# %% [markdown]
# ##### Changing Categorical data to numeric data

# %%
data._get_numeric_data().columns
# Out:
# Index(['year', 'household_size', 'age_of_respondent', 'age'], dtype='object')

# %%
data.columns
# Out:
# Index(['country', 'year', 'uniqueid', 'bank_account', 'location_type',
#        'cellphone_access', 'household_size', 'age_of_respondent',
#        'gender_of_respondent', 'relationship_with_head', 'marital_status',
#        'education_level', 'job_type', 'gender', 'age'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
data['country'] = le.fit_transform(data['country'])
data['bank_account'] = le.fit_transform(data['bank_account'])
data['location_type'] = le.fit_transform(data['location_type'])
data[ 'cellphone_access'] = le.fit_transform(data[ 'cellphone_access'])
data['gender'] = le.fit_transform(data['gender'])
data['relationship_with_head'] = le.fit_transform(data['relationship_with_head'])
data['marital_status'] = le.fit_transform(data['marital_status'])
data['education_level'] = le.fit_transform(data['education_level'])
data['job_type'] = le.fit_transform(data['job_type'])

# %%
data.drop(['gender_of_respondent','uniqueid','age_of_respondent',],axis=1,inplace=True)

# %%
#checking correlation
data.corr()
# Out:
#                              country          year  bank_account  \
# country                 1.000000e+00 -9.499129e-02 -1.613624e-01
# year                   -9.499129e-02  1.000000e+00  1.123181e-01
# bank_account           -1.613624e-01  1.123181e-01  1.000000e+00
# location_type           1.522850e-01  2.146211e-01  8.728829e-02
# cellphone_access       -1.500027e-01 -6.650550e-02  2.096688e-01
# household_size         -1.191581e-01 -5.226357e-02 -2.832647e-02
# relationship_with_head  1.304076e-01  1.801075e-03 -7.085305e-02
# marital_status          9.281791e-03 -2.618701e-02 -3.873874e-02
# education_level        -5.070637e-02  1.738686e-01  3.237677e-01
# job_type                3.810656e-01  2.663232e-01 -6.417100e-02
# gender                 -2.705450e-02  3.174150e-04  1.172339e-01
# age                    -2.621446e-13  1.304839e-13 -2.409165e-15
#
#                         location_type  cellphone_access  household_size  \
# ...

# %%
sns.heatmap(data.corr(),annot=True)

# %%
last_column= data.pop('bank_account')
data.insert(0,'bank_account',last_column)

# %%
data.head()
# Out:
#    bank_account  country  year  location_type  cellphone_access  \
# 0             1        0  2018              0                 1
# 1             0        0  2018              0                 0
# 2             1        0  2018              1                 1
# 3             0        0  2018              0                 1
# 4             0        0  2018              1                 0
#
#    household_size  relationship_with_head  marital_status  education_level  \
# 0               3                       5               2                3
# 1               5                       1               4                0
# 2               5                       3               3                5
# 3               5                       1               2                2
# 4               8                       0               3                2
#
#    job_type  gender       age
# 0         9       0  38.80522
# 1         4       0  38.80522
# 2         9       1  38.80522
# ...

# %% [markdown]
# #### FEATURE SELECTION

# %%
#we are predicting those who have bank account
from sklearn.feature_selection import SelectKBest, chi2

features= SelectKBest(score_func = chi2, k = 'all')

# %%
X = data.iloc[:, 1:]
y = data.iloc[:,[0]]

# %%
X
# Out:
#        country  year  location_type  cellphone_access  household_size  \
# 0            0  2018              0                 1               3
# 1            0  2018              0                 0               5
# 2            0  2018              1                 1               5
# 3            0  2018              0                 1               5
# 4            0  2018              1                 0               8
# ...        ...   ...            ...               ...             ...
# 23519        3  2018              0                 1               4
# 23520        3  2018              0                 1               2
# 23521        3  2018              0                 1               5
# 23522        3  2018              1                 1               7
# 23523        3  2018              0                 1              10
#
#        relationship_with_head  marital_status  education_level  job_type  \
# ...

# %%
y
# Out:
#        bank_account
# 0                 1
# 1                 0
# 2                 1
# 3                 0
# 4                 0
# ...             ...
# 23519             0
# 23520             0
# 23521             0
# 23522             0
# 23523             0
#
# [23524 rows x 1 columns]

# %%
data_features = features.fit(X,y)
df_scores = pd.DataFrame(data_features.scores_, columns = ['scores'])
df_columns = pd.DataFrame(X.columns)

# %%
feature_rank = pd.concat([df_columns, df_scores],axis=1)
feature_rank.columns = ['Features','Score']
feature_rank
# Out:
#                   Features         Score
# 0                  country  4.360517e+02
# 1                     year  1.056424e-01
# 2            location_type  1.092828e+02
# 3         cellphone_access  2.668432e+02
# 4           household_size  2.466387e+01
# 5   relationship_with_head  1.909298e+02
# 6           marital_status  1.473779e+01
# 7          education_level  1.795612e+03
# 8                 job_type  1.700678e+02
# 9                   gender  1.907225e+02
# 10                     age  7.274956e-25

# %%
feature_rank.nlargest(10,'Score')
# Out:
#                  Features        Score
# 7         education_level  1795.611669
# 0                 country   436.051655
# 3        cellphone_access   266.843216
# 5  relationship_with_head   190.929768
# 9                  gender   190.722499
# 8                job_type   170.067820
# 2           location_type   109.282841
# 4          household_size    24.663868
# 6          marital_status    14.737790
# 1                    year     0.105642

# %% [markdown]
# #### Modeling/Machine Learning

# %%
from sklearn.model_selection import train_test_split
x = data.loc[:,['education_level','country','cellphone_access','relationship_with_head','gender','job_type','location_type','household_size','marital_status','year']]
y = data['bank_account']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=11)

# %%
sns.regplot(x="bank_account", y='education_level', color="blue", data=data)
plt.ylim(0,)
# Out:
# C:\Users\Honour Jesus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# (0, 5.265176600441501)

# %% [markdown]
# #### SVector Classifier

# %%
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier as knc
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,recall_score,precision_score
svc= SVC()
svc.fit(x_train,y_train)
y_pred = svc.predict(x_test)

# %%
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# Accuracy score: 0.8641258146783791
# [[6099    0]
#  [ 959    0]]
#               precision    recall  f1-score   support
#
#            0       0.86      1.00      0.93      6099
#            1       0.00      0.00      0.00       959
#
#     accuracy                           0.86      7058
#    macro avg       0.43      0.50      0.46      7058
# weighted avg       0.75      0.86      0.80      7058
# C:\Users\Honour Jesus\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)
# Out:
# C:\Users\Honour Jesus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.regplot(y_test,y_pred)
# Out:
# C:\Users\Honour Jesus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, svc.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('SVC (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-59-a91706381684> in <module>()
#       1 from matplotlib.colors import ListedColormap
#       2 X_set, y_set = x_train, y_train
# ----> 3 X1, X2 = np.meshgrid(np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01),
#       4                      np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
#       5 plt.contourf(X1, X2, svc.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# ...

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, svc.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('SVC (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### CatBoost Classifier

# %%
import catboost as cb 
mcb = cb.CatBoostClassifier()
mcb.fit(x_train, y_train)
print(mcb)

# %%
y_pred = mcb.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, mcb.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('CatBoost (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, mcb.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('CatBoost (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
clasifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 11)
clasifier.fit(x_train, y_train)

# %%
y_pred =clasifier.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Decision Tree (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Decision Tree (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(x_train, y_train)

# %%
y_pred =classifier.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('blue', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('blue', 'green'))(i), label = j)
plt.title('Naive Bayes (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, classifier.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('blue', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('blue', 'green'))(i), label = j)
plt.title('Naive Bayes(Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### KNearest Neighbour Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
knn.fit(x_train, y_train)

# %%
y_pred =knn.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, knn.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('blue', 'red')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('blue', 'red'))(i), label = j)
plt.title('K-NN (Training set)')
plt.xlabel('country_people')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, knn.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('blue', 'red')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('blue', 'red'))(i), label = j)
plt.title('K-NN (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train, y_train)
print(rfc)

# %%
y_pred = rfc.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, rfc.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('RandomForest (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, rfc.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('K-NN (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### Normal SVM Classifier

# %%
from sklearn.svm import SVC
nsvm = SVC(kernel = 'linear', random_state = 11)
nsvm.fit(x_train, y_train)

# %%
y_pred =nsvm.predict(x_test)
print(f'Accuracy score: {metrics.accuracy_score(y_test,y_pred)}')
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# #### Visualization

# %%
sns.scatterplot(y_test,y_pred)

# %%
sns.distplot(y_test-y_pred)

# %%
sns.regplot(y_test,y_pred)

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_train, y_train
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2,nsvm.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('SVC (Training set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %%
from matplotlib.colors import ListedColormap
X_set, y_set = x_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, nsvm.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('NSVM (Test set)')
plt.xlabel('Country_People')
plt.ylabel('Bank_Account')
plt.legend()
plt.show()

# %% [markdown]
# #### Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C':[0.1,1,10,100],'gamma':[1,0.1,0.01,0.001]}
grid= GridSearchCV(SVC(),param_grid,refit= True,verbose=2)#verbose= 2 means one line per epoch,epoch means iterations
grid.fit(x_train,y_train)

# %%
grid_pred= grid.predict(x_test)
print(f'Accuracy Score: {metrics.accuracy_score(y_test,grid_pred)}')
print(confusion_matrix(y_test, grid_pred))
print(classification_report(y_test, grid_pred))

# %%
sns.scatterplot(y_test,grid_pred)

# %%
sns.distplot(y_test-grid_pred)

# %%
sns.regplot(y_test,grid_pred)

# %%
#open a file to store your data
import pickle
file=open('Financial_Inclusion_Africa.pkl','wb')
#dump information to the file
pickle.dump(mcb, file)
